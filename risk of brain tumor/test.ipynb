# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./risk_of_brain_tumor.csv")

# %%
data
# Out:
#          Patient Id  Age  Gender  Genetic Risk  Occupational Hazards  \
# 0      0         P1   33       1             3                     4
# 1      1       P240   35       1             2                     4
# 2      2       P239   42       1             4                     3
# 3      3        P10   17       1             4                     3
# 4      4       P238   22       0             3                     4
# ..   ...        ...  ...     ...           ...                   ...
# 358  358        P32   27       1             2                     3
# 359  359       P320   65       1             7                     7
# 360  360       P321   38       0             2                     3
# 361  361       P322   19       1             3                     2
# 362  362       P323   33       1             7                     7
#
#      Headache  Seizure Rate  Convulsion Rate  Blurred Vision  ...  \
# 0           2             2                2               2  ...
# ...

# %%
x = data["Age"]
y = data["Syncope Rate"]

# %%
plt.scatter(x,y)
