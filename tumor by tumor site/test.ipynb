# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./Brain Cancer by Tumor Site.csv")

# %%
data

# %%
benign_data = data[data["Type of Tumor"] == "Benign/Borderline"]
benign_data

# %%
malignant_data = data[data["Type of Tumor"] == "Malignant"]
malignant_data

# %%
malignant_data_x = malignant_data["Data Collection Starting Year"]
malignant_data_x

# %%
malignant_data_y = malignant_data["Total Population"]
malignant_data_y

# %%
plt.plot(malignant_data_x,malignant_data_y)
plt.ylim(39865121,40576293)
# Out:
# (39865121.0, 40576293.0)

# %%
x = []
